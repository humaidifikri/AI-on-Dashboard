# %%
import pandas as pd
from deep_translator import GoogleTranslator,MyMemoryTranslator,LibreTranslator
import requests

# %%
df1 = pd.read_csv('../data/raw_food/FOOD-DATA-GROUP1.csv')
df2 = pd.read_csv('../data/raw_food/FOOD-DATA-GROUP2.csv')
df3 = pd.read_csv('../data/raw_food/FOOD-DATA-GROUP3.csv')
df4 = pd.read_csv('../data/raw_food/FOOD-DATA-GROUP4.csv')
df5 = pd.read_csv('../data/raw_food/FOOD-DATA-GROUP5.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                              food  Caloric Value  \
# 0             0           0                      cream cheese             51
# 1             1           1                 neufchatel cheese            215
# 2             2           2  requeijao cremoso light catupiry             49
# 3             3           3                    ricotta cheese             30
# 4             4           4              cream cheese low fat             30
#
#     Fat  Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  \
# 0   5.0             2.9                   1.3                 0.200
# 1  19.4            10.9                   4.9                 0.800
# 2   3.6             2.3                   0.9                 0.000
# 3   2.0             1.3                   0.5                 0.002
# 4   2.3             1.4                   0.6                 0.042
#
#    Carbohydrates  Sugars  ...  Calcium  Copper   Iron  Magnesium  Manganese  \
# ...

# %%
def translate_food(name):
    try:
        return GoogleTranslator(source='en', target='id').translate(name)
    except:
        return name

# %%
df1['food'] = df1['food'].apply(libre_translate)
# Out:
# Error translating 'cream cheese': HTTPSConnectionPool(host='libretranslate.de', port=443): Max retries exceeded with url: /translate (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000024FCF745150>, 'Connection to libretranslate.de timed out. (connect timeout=None)'))
# Error translating 'neufchatel cheese': HTTPSConnectionPool(host='libretranslate.de', port=443): Max retries exceeded with url: /translate (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000024FCF745870>, 'Connection to libretranslate.de timed out. (connect timeout=None)'))
# Error translating 'requeijao cremoso light catupiry': HTTPSConnectionPool(host='libretranslate.de', port=443): Max retries exceeded with url: /translate (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x0000024FCF7442E0>, 'Connection to libretranslate.de timed out. (connect timeout=None)'))
# ...

# %%
df1.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                              food  Caloric Value  \
# 0             0           0                      cream cheese             51
# 1             1           1                 neufchatel cheese            215
# 2             2           2  requeijao cremoso light catupiry             49
# 3             3           3                    ricotta cheese             30
# 4             4           4              cream cheese low fat             30
#
#     Fat  Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  \
# 0   5.0             2.9                   1.3                 0.200
# 1  19.4            10.9                   4.9                 0.800
# 2   3.6             2.3                   0.9                 0.000
# 3   2.0             1.3                   0.5                 0.002
# 4   2.3             1.4                   0.6                 0.042
#
#    Carbohydrates  Sugars  ...  Calcium  Copper   Iron  Magnesium  Manganese  \
# ...

# %%
df2['food'] = df2['food'].apply(translate_food)
df2.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                  food  Caloric Value   Fat  \
# 0             0           0  minuman telur kopyok            224  10.6
# 1             1           1            Cahaya bir             96   0.0
# 2             2           2         Budweiser bir             12   0.0
# 3             3           3   Weizenbier Erdinger            220  18.0
# 4             4           4  Budweiser Cahaya Bir              9   0.0
#
#    Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  \
# 0             6.6                   3.3                   0.5           20.4
# 1             0.0                   0.0                   0.0            5.4
# 2             0.0                   0.0                   0.0            0.9
# 3            13.0                   1.0                   0.0            0.0
# 4             0.0                   0.0                   0.0            0.4
#
#    Sugars  ...  Calcium  Copper   Iron  Magnesium  Manganese  Phosphorus  \
# ...

# %%
df3['food'] = df3['food'].apply(translate_food)
df3.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0          food  Caloric Value    Fat  \
# 0             0           0      nektarin             66  0.500
# 1             1           1     Emas Kiwi             51  0.200
# 2             2           2  Pear Raw Raw              8  0.072
# 3             3           3         nanas             45  0.100
# 4             4           4         Rowan            253  4.600
#
#    Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  \
# 0           0.066                 0.100                 0.200           15.8
# 1           0.008                 0.099                 0.051           12.8
# 2           0.000                 0.000                 0.000            1.9
# 3           0.074                 0.001                 0.087           11.8
# 4           0.600                 0.000                 0.000           54.5
#
#    Sugars  ...  Calcium  Copper   Iron  Magnesium  Manganese  Phosphorus  \
# ...

# %%
df4['food'] = df4['food'].apply(translate_food)
df4.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                        food  Caloric Value   Fat  \
# 0             0           0       Cokelat Puding Gratis            105   0.3
# 1             1           1              puding tapioka            143   4.3
# 2             2           2  Tapioca Pudding Fat Gratis            105   0.4
# 3             3           3                puding beras            122   2.4
# 4             4           4               Puding jagung            328  12.6
#
#    Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  \
# 0             0.0                  0.00                 0.000           23.6
# 1             1.1                  2.80                 0.088           23.9
# 2             0.1                  0.08                 0.067           23.9
# 3             1.4                  0.60                 0.100           20.8
# 4             6.3                  3.90                 1.400           42.4
#
# ...

# %%
df5['food'] = df5['food'].apply(translate_food)
df5.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                         food  Caloric Value  \
# 0             0           0      margarin dengan yoghurt             88
# 1             1           1  mentega biji bunga matahari             99
# 2             2           2              Minyak Hazelnut            120
# 3             3           3         Minyak Ikan Menhaden           1966
# 4             4           4         minyak ikan cod hati            123
#
#      Fat  Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  \
# 0    9.8             1.9                   5.6                   2.0
# 1    8.8             0.7                   6.2                   1.6
# 2   13.6             1.0                  10.6                   1.4
# 3  218.0            66.3                  58.2                  74.5
# 4   13.6             3.1                   6.4                   3.1
#
#    Carbohydrates  Sugars  ...  Calcium  Copper   Iron  Magnesium  Manganese  \
# ...

# %%
all_df = pd.concat([df1,df2,df3,df4,df5])
all_df
# Out:
#      Unnamed: 0.1  Unnamed: 0                              food  \
# 0               0           0                         krim keju
# 1               1           1                   keju neufchatel
# 2               2           2  Requeijao Cremoso Light Catupiry
# 3               3           3                      Keju ricotta
# 4               4           4            krim keju rendah lemak
# ..            ...         ...                               ...
# 717           717         717                    telinga Yahudi
# 718           718         718                       jamur enoki
# 719           719         719                       Jamur Morel
# 720           720         720           Jamur portabella mentah
# 721           721         721                       Jamur tiram
#
#      Caloric Value     Fat  Saturated Fats  Monounsaturated Fats  \
# 0               51   5.000           2.900                 1.300
# ...

# %%
all_df.drop(columns=['Unnamed: 0.1','Unnamed: 0'],inplace=True)
all_df.to_csv('../data/raw_food_translated.csv',index=False)

# %%
raw_food = pd.read_csv('../data/raw_food_translated.csv')
raw_food
# Out:
#                                   food  Caloric Value     Fat  Saturated Fats  \
# 0                            krim keju             51   5.000           2.900
# 1                      keju neufchatel            215  19.400          10.900
# 2     Requeijao Cremoso Light Catupiry             49   3.600           2.300
# 3                         Keju ricotta             30   2.000           1.300
# 4               krim keju rendah lemak             30   2.300           1.400
# ...                                ...            ...     ...             ...
# 2390                    telinga Yahudi             25   0.095           0.000
# 2391                       jamur enoki              1   0.099           0.027
# 2392                       Jamur Morel              4   0.070           0.056
# 2393           Jamur portabella mentah             19   0.300           0.036
# 2394                       Jamur tiram              5   0.035           0.016
#
# ...
