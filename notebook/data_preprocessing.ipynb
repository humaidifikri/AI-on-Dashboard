# %%
import pandas as pd
import openai

# %%
df = pd.read_csv('../data/raw_food_translated.csv')
df
# Out:
#                                   food  Caloric Value     Fat  Saturated Fats  \
# 0                            krim keju             51   5.000           2.900
# 1                      keju neufchatel            215  19.400          10.900
# 2     Requeijao Cremoso Light Catupiry             49   3.600           2.300
# 3                         Keju ricotta             30   2.000           1.300
# 4               krim keju rendah lemak             30   2.300           1.400
# ...                                ...            ...     ...             ...
# 2390                    telinga Yahudi             25   0.095           0.000
# 2391                       jamur enoki              1   0.099           0.027
# 2392                       Jamur Morel              4   0.070           0.056
# 2393           Jamur portabella mentah             19   0.300           0.036
# 2394                       Jamur tiram              5   0.035           0.016
#
# ...

# %% [markdown]
# Menyesuaikan Terjemahan

# %%
df[df['food'].str.contains('cahaya', case=False, na=False)]
# Out:
#                            food  Caloric Value   Fat  Saturated Fats  \
# 552                  Cahaya bir             96  0.00             0.0
# 555        Budweiser Cahaya Bir              9  0.00             0.0
# 578               Cahaya anggur             73  0.00             0.0
# 1971        Cahaya sirup jagung             62  0.09             0.0
# 1997  Cahaya Dressing Keju Biru             14  0.40             0.1
# 2011             cahaya mayones             36  3.30             0.5
#
#       Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  Sugars  \
# 552                    0.0                   0.0            5.4     0.3
# 555                    0.0                   0.0            0.4     0.0
# 578                    0.0                   0.0            1.7     1.7
# 1971                   0.0                   0.0           16.9    16.9
# 1997                   0.2                   0.1            2.1     0.6
# ...

# %%
df['food'] = df['food'].str.replace(r'\b[Cc]ahaya\b', 'Ringan', regex=True)
df[df['food'].str.contains('Ringan', case=False, na=False)]
# Out:
#                            food  Caloric Value   Fat  Saturated Fats  \
# 552                  Ringan bir             96  0.00             0.0
# 555        Budweiser Ringan Bir              9  0.00             0.0
# 578               Ringan anggur             73  0.00             0.0
# 677    Kue makanan ringan spons            157  4.80             1.7
# 1971        Ringan sirup jagung             62  0.09             0.0
# 1997  Ringan Dressing Keju Biru             14  0.40             0.1
# 2011             Ringan mayones             36  3.30             0.5
#
#       Monounsaturated Fats  Polyunsaturated Fats  Carbohydrates  Sugars  \
# 552                    0.0                   0.0            5.4     0.3
# 555                    0.0                   0.0            0.4     0.0
# 578                    0.0                   0.0            1.7     1.7
# 677                    2.1                   0.8           26.9    15.7
# ...
