# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# - Patient_ID Unique identifier for each patient.
# - Age Age of the patient.
# - Gender Gender of the patient (Male, Female).
# - Weight_kg Weight of the patient in kilograms.
# - Height_cm Height of the patient in centimeters.
# - BMI Body Mass Index calculated as Weight (kg) / (Height (m)^2).
# - Disease_Type Primary disease diagnosed (Diabetes, Hypertension, Obesity, or None).
# - Severity Severity of the disease (Mild, Moderate, Severe).
# - Physical_Activity_Level Level of physical activity (Sedentary, Moderate, Active).
# - Daily_Caloric_Intake Average daily calorie consumption.
# - Cholesterol_mg/dL Cholesterol level in mg/dL.
# - Blood_Pressure_mmHg Average blood pressure in mmHg.
# - Glucose_mg/dL Blood glucose level in mg/dL.
# - Dietary_Restrictions Known dietary restrictions (Low_Sodium, Low_Sugar, None).
# - Allergies Known food allergies (Peanuts, Gluten, None).
# - Preferred_Cuisine Patient's preferred cuisine (Indian, Italian, Chinese, Mexican).
# - Weekly_Exercise_Hours Number of hours exercised per week.
# - Adherence_to_Diet_Plan Patient's adherence to a suggested diet plan (percentage).
# - Dietary_Nutrient_Imbalance_Score A score indicating nutrient imbalance in the patient's diet.
# - Target Column
# - Diet_Recommendation: Suggested dietary plan based on individual health conditions:
# - Low_Carb: For managing diabetes or weight-related concerns.
# - Low_Sodium: For hypertension or cardiovascular health.
# - Balanced: For general health improvement or non-specific requirements.

# %%
df = pd.read_csv('../data/diet_recommendations_dataset.csv')
df
# Out:
#     Patient_ID  Age  Gender  Weight_kg  Height_cm   BMI  Disease_Type  \
# 0        P0001   56    Male       58.4        160  22.8       Obesity
# 1        P0002   69    Male      101.2        169  35.4      Diabetes
# 2        P0003   46  Female       63.5        173  21.2  Hypertension
# 3        P0004   32    Male       58.1        164  21.6           NaN
# 4        P0005   60    Male       79.5        197  20.5      Diabetes
# ..         ...  ...     ...        ...        ...   ...           ...
# 995      P0996   18    Male       72.1        160  28.2       Obesity
# 996      P0997   35  Female      104.0        171  35.6  Hypertension
# 997      P0998   49  Female       56.0        182  16.9       Obesity
# 998      P0999   64    Male       66.6        185  19.5      Diabetes
# 999      P1000   66  Female      101.3        194  26.9       Obesity
#
#      Severity Physical_Activity_Level  Daily_Caloric_Intake  \
# 0    Moderate                Moderate                  3079
# 1        Mild                Moderate                  3032
# 2        Mild               Sedentary                  1737
# 3        Mild                Moderate                  2657
# 4    Moderate               Sedentary                  3496
# ..        ...                     ...                   ...
# 995  Moderate                  Active                  2639
# 996  Moderate                Moderate                  1661
# 997    Severe                Moderate                  3102
# 998    Severe                  Active                  3235
# 999    Severe                Moderate                  2042
#
#      Cholesterol_mg/dL  Blood_Pressure_mmHg  Glucose_mg/dL  \
# 0                173.3                  133          116.3
# 1                199.2                  120          137.1
# 2                181.0                  121          109.6
# 3                168.2                  144          159.4
# 4                200.4                  172          182.3
# ..                 ...                  ...            ...
# 995              152.6                  166          125.1
# 996              172.2                  126           78.6
# 997              228.0                  148           70.2
# 998              170.1                  177          138.0
# 999              158.0                  164          114.7
#
#     Dietary_Restrictions Allergies Preferred_Cuisine  Weekly_Exercise_Hours  \
# 0                    NaN   Peanuts           Mexican                    3.1
# 1                    NaN   Peanuts           Chinese                    4.5
# 2                    NaN   Peanuts           Chinese                    3.8
# 3                    NaN       NaN           Mexican                    4.3
# 4              Low_Sugar       NaN           Italian                    9.8
# ..                   ...       ...               ...                    ...
# 995            Low_Sugar       NaN           Mexican                    4.4
# 996           Low_Sodium       NaN           Chinese                    7.3
# 997            Low_Sugar       NaN            Indian                    8.9
# 998            Low_Sugar    Gluten            Indian                    6.7
# 999                  NaN   Peanuts           Italian                    2.0
#
#      Adherence_to_Diet_Plan  Dietary_Nutrient_Imbalance_Score  \
# 0                      96.6                               3.1
# 1                      63.2                               0.6
# 2                      57.5                               4.6
# 3                      54.5                               0.4
# 4                      78.2                               4.7
# ..                      ...                               ...
# 995                    55.0                               3.6
# 996                    88.8                               2.9
# 997                    68.6                               4.8
# 998                    52.0                               0.1
# 999                    68.2                               3.7
#
#     Diet_Recommendation
# 0              Balanced
# 1              Low_Carb
# 2            Low_Sodium
# 3              Balanced
# 4              Low_Carb
# ..                  ...
# 995            Balanced
# 996          Low_Sodium
# 997            Balanced
# 998            Low_Carb
# 999            Balanced
#
# [1000 rows x 20 columns]

# %%
df.drop(columns=['Patient_ID'],inplace=True)

# %%
df.head()
# Out:
#    Age  Gender  Weight_kg  Height_cm   BMI  Disease_Type  Severity  \
# 0   56    Male       58.4        160  22.8       Obesity  Moderate
# 1   69    Male      101.2        169  35.4      Diabetes      Mild
# 2   46  Female       63.5        173  21.2  Hypertension      Mild
# 3   32    Male       58.1        164  21.6           NaN      Mild
# 4   60    Male       79.5        197  20.5      Diabetes  Moderate
#
#   Physical_Activity_Level  Daily_Caloric_Intake  Cholesterol_mg/dL  \
# 0                Moderate                  3079              173.3
# 1                Moderate                  3032              199.2
# 2               Sedentary                  1737              181.0
# 3                Moderate                  2657              168.2
# 4               Sedentary                  3496              200.4
#
#    Blood_Pressure_mmHg  Glucose_mg/dL Dietary_Restrictions Allergies  \
# 0                  133          116.3                  NaN   Peanuts
# 1                  120          137.1                  NaN   Peanuts
# 2                  121          109.6                  NaN   Peanuts
# 3                  144          159.4                  NaN       NaN
# 4                  172          182.3            Low_Sugar       NaN
#
#   Preferred_Cuisine  Weekly_Exercise_Hours  Adherence_to_Diet_Plan  \
# 0           Mexican                    3.1                    96.6
# 1           Chinese                    4.5                    63.2
# 2           Chinese                    3.8                    57.5
# 3           Mexican                    4.3                    54.5
# 4           Italian                    9.8                    78.2
#
#    Dietary_Nutrient_Imbalance_Score Diet_Recommendation
# 0                               3.1            Balanced
# 1                               0.6            Low_Carb
# 2                               4.6          Low_Sodium
# 3                               0.4            Balanced
# 4                               4.7            Low_Carb

# %%
df.isna().sum()
# Out:
# Age                                   0
# Gender                                0
# Weight_kg                             0
# Height_cm                             0
# BMI                                   0
# Disease_Type                        204
# Severity                              0
# Physical_Activity_Level               0
# Daily_Caloric_Intake                  0
# Cholesterol_mg/dL                     0
# Blood_Pressure_mmHg                   0
# Glucose_mg/dL                         0
# Dietary_Restrictions                334
# Allergies                           323
# Preferred_Cuisine                     0
# Weekly_Exercise_Hours                 0
# Adherence_to_Diet_Plan                0
# Dietary_Nutrient_Imbalance_Score      0
# Diet_Recommendation                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                Age    Weight_kg   Height_cm          BMI  \
# count  1000.000000  1000.000000  1000.00000  1000.000000
# mean     49.857000    84.602400   174.81700    28.191600
# std      18.114267    20.088121    14.33377     8.040136
# min      18.000000    50.000000   150.00000    13.000000
# 25%      35.000000    66.600000   162.00000    22.075000
# 50%      50.000000    85.200000   175.00000    27.450000
# 75%      66.000000   102.000000   187.00000    33.425000
# max      79.000000   119.700000   199.00000    52.400000
#
#        Daily_Caloric_Intake  Cholesterol_mg/dL  Blood_Pressure_mmHg  \
# count           1000.000000        1000.000000          1000.000000
# mean            2475.064000         199.717900           144.993000
# std              565.017032          29.080614            20.245712
# min             1500.000000         150.400000           110.000000
# 25%             1984.750000         174.300000           128.000000
# 50%             2470.500000         199.850000           145.000000
# 75%             2937.250000         224.850000           163.000000
# max             3498.000000         249.900000           179.000000
#
#        Glucose_mg/dL  Weekly_Exercise_Hours  Adherence_to_Diet_Plan  \
# count    1000.000000            1000.000000              1000.00000
# mean      136.867600               5.166000                74.88430
# std        37.934819               2.847995                14.82638
# min        70.200000               0.000000                50.00000
# 25%       105.000000               2.800000                62.00000
# 50%       138.000000               5.200000                74.20000
# 75%       170.650000               7.600000                88.20000
# max       200.000000              10.000000               100.00000
#
#        Dietary_Nutrient_Imbalance_Score
# count                       1000.000000
# mean                           2.469200
# std                            1.459631
# min                            0.000000
# 25%                            1.200000
# 50%                            2.400000
# 75%                            3.700000
# max                            5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               1000 non-null   int64
#  1   Gender                            1000 non-null   object
#  2   Weight_kg                         1000 non-null   float64
#  3   Height_cm                         1000 non-null   int64
#  4   BMI                               1000 non-null   float64
#  5   Disease_Type                      796 non-null    object
#  6   Severity                          1000 non-null   object
#  7   Physical_Activity_Level           1000 non-null   object
#  8   Daily_Caloric_Intake              1000 non-null   int64
#  9   Cholesterol_mg/dL                 1000 non-null   float64
#  10  Blood_Pressure_mmHg               1000 non-null   int64
#  11  Glucose_mg/dL                     1000 non-null   float64
#  12  Dietary_Restrictions              666 non-null    object
#  13  Allergies                         677 non-null    object
#  14  Preferred_Cuisine                 1000 non-null   object
#  15  Weekly_Exercise_Hours             1000 non-null   float64
#  16  Adherence_to_Diet_Plan            1000 non-null   float64
#  17  Dietary_Nutrient_Imbalance_Score  1000 non-null   float64
#  18  Diet_Recommendation               1000 non-null   object
# dtypes: float64(7), int64(4), object(8)
# memory usage: 148.6+ KB

# %%
for col in df.columns:
    if df[col].isna().sum() > 0:
        df[col] = df[col].fillna('None')
df
# Out:
#      Age  Gender  Weight_kg  Height_cm   BMI  Disease_Type  Severity  \
# 0     56    Male       58.4        160  22.8       Obesity  Moderate
# 1     69    Male      101.2        169  35.4      Diabetes      Mild
# 2     46  Female       63.5        173  21.2  Hypertension      Mild
# 3     32    Male       58.1        164  21.6          None      Mild
# 4     60    Male       79.5        197  20.5      Diabetes  Moderate
# ..   ...     ...        ...        ...   ...           ...       ...
# 995   18    Male       72.1        160  28.2       Obesity  Moderate
# 996   35  Female      104.0        171  35.6  Hypertension  Moderate
# 997   49  Female       56.0        182  16.9       Obesity    Severe
# 998   64    Male       66.6        185  19.5      Diabetes    Severe
# 999   66  Female      101.3        194  26.9       Obesity    Severe
#
#     Physical_Activity_Level  Daily_Caloric_Intake  Cholesterol_mg/dL  \
# 0                  Moderate                  3079              173.3
# 1                  Moderate                  3032              199.2
# 2                 Sedentary                  1737              181.0
# 3                  Moderate                  2657              168.2
# 4                 Sedentary                  3496              200.4
# ..                      ...                   ...                ...
# 995                  Active                  2639              152.6
# 996                Moderate                  1661              172.2
# 997                Moderate                  3102              228.0
# 998                  Active                  3235              170.1
# 999                Moderate                  2042              158.0
#
#      Blood_Pressure_mmHg  Glucose_mg/dL Dietary_Restrictions Allergies  \
# 0                    133          116.3                 None   Peanuts
# 1                    120          137.1                 None   Peanuts
# 2                    121          109.6                 None   Peanuts
# 3                    144          159.4                 None      None
# 4                    172          182.3            Low_Sugar      None
# ..                   ...            ...                  ...       ...
# 995                  166          125.1            Low_Sugar      None
# 996                  126           78.6           Low_Sodium      None
# 997                  148           70.2            Low_Sugar      None
# 998                  177          138.0            Low_Sugar    Gluten
# 999                  164          114.7                 None   Peanuts
#
#     Preferred_Cuisine  Weekly_Exercise_Hours  Adherence_to_Diet_Plan  \
# 0             Mexican                    3.1                    96.6
# 1             Chinese                    4.5                    63.2
# 2             Chinese                    3.8                    57.5
# 3             Mexican                    4.3                    54.5
# 4             Italian                    9.8                    78.2
# ..                ...                    ...                     ...
# 995           Mexican                    4.4                    55.0
# 996           Chinese                    7.3                    88.8
# 997            Indian                    8.9                    68.6
# 998            Indian                    6.7                    52.0
# 999           Italian                    2.0                    68.2
#
#      Dietary_Nutrient_Imbalance_Score Diet_Recommendation
# 0                                 3.1            Balanced
# 1                                 0.6            Low_Carb
# 2                                 4.6          Low_Sodium
# 3                                 0.4            Balanced
# 4                                 4.7            Low_Carb
# ..                                ...                 ...
# 995                               3.6            Balanced
# 996                               2.9          Low_Sodium
# 997                               4.8            Balanced
# 998                               0.1            Low_Carb
# 999                               3.7            Balanced
#
# [1000 rows x 19 columns]

# %%
cat_cols = df.select_dtypes(include='object',exclude=['float64','int64']).columns
num_cols = df.select_dtypes(include=['float64','int64'],exclude='object').columns
print(cat_cols,num_cols)
print(len(cat_cols),len(num_cols))
# Out:
# Index(['Gender', 'Disease_Type', 'Severity', 'Physical_Activity_Level',
#        'Dietary_Restrictions', 'Allergies', 'Preferred_Cuisine',
#        'Diet_Recommendation'],
#       dtype='object') Index(['Age', 'Weight_kg', 'Height_cm', 'BMI', 'Daily_Caloric_Intake',
#        'Cholesterol_mg/dL', 'Blood_Pressure_mmHg', 'Glucose_mg/dL',
#        'Weekly_Exercise_Hours', 'Adherence_to_Diet_Plan',
#        'Dietary_Nutrient_Imbalance_Score'],
#       dtype='object')
# 8 11

# %%
plt.figure(figsize=(20,30))

i=1
for col in cat_cols:
    plt.subplot(4,2,i)
    sns.countplot(x=df[col],hue=df['Diet_Recommendation'])
    i+=1

# %%
plt.figure(figsize=(20,30))

i=1
for col in num_cols:
    plt.subplot(6,2,i)
#     sns.histplot(x=df[col],hue=df['Diet_Recommendation'])
    sns.kdeplot(x=df[col],hue=df['Diet_Recommendation'])
    i+=1

# %%
corr = df[num_cols].corr()

plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True);
