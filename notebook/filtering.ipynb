# %%
import pandas as pd

# %%
# pd.options.display.max_columns(50)
df = pd.read_csv("../data/raw_food_translated.csv")
df['food'] = df['food'].str.title()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2395 entries, 0 to 2394
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   food                  2395 non-null   object
#  1   Caloric Value         2395 non-null   int64
#  2   Fat                   2395 non-null   float64
#  3   Saturated Fats        2395 non-null   float64
#  4   Monounsaturated Fats  2395 non-null   float64
#  5   Polyunsaturated Fats  2395 non-null   float64
#  6   Carbohydrates         2395 non-null   float64
#  7   Sugars                2395 non-null   float64
#  8   Protein               2395 non-null   float64
#  9   Dietary Fiber         2395 non-null   float64
#  10  Cholesterol           2395 non-null   float64
#  11  Sodium                2395 non-null   float64
#  12  Water                 2395 non-null   float64
#  13  Vitamin A             2395 non-null   float64
# ...

# %%
df.isna().sum()
# Out:
# food                    0
# Caloric Value           0
# Fat                     0
# Saturated Fats          0
# Monounsaturated Fats    0
# Polyunsaturated Fats    0
# Carbohydrates           0
# Sugars                  0
# Protein                 0
# Dietary Fiber           0
# Cholesterol             0
# Sodium                  0
# Water                   0
# Vitamin A               0
# Vitamin B1              0
# Vitamin B11             0
# Vitamin B12             0
# Vitamin B2              0
# Vitamin B3              0
# Vitamin B5              0
# Vitamin B6              0
# Vitamin C               0
# Vitamin D               0
# Vitamin E               0
# Vitamin K               0
# Calcium                 0
# Copper                  0
# Iron                    0
# Magnesium               0
# Manganese               0
# Phosphorus              0
# Potassium               0
# Selenium                0
# Zinc                    0
# Nutrition Density       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_main_nutrients = df.loc[:,['food','Caloric Value','Fat','Sugars','Protein','Water']]
df_main_nutrients
# Out:
#                                   food  Caloric Value     Fat  Sugars  \
# 0                            Krim Keju             51   5.000   0.500
# 1                      Keju Neufchatel            215  19.400   2.700
# 2     Requeijao Cremoso Light Catupiry             49   3.600   3.400
# 3                         Keju Ricotta             30   2.000   0.091
# 4               Krim Keju Rendah Lemak             30   2.300   0.900
# ...                                ...            ...     ...     ...
# 2390                    Telinga Yahudi             25   0.095   0.000
# 2391                       Jamur Enoki              1   0.099   0.034
# 2392                       Jamur Morel              4   0.070   0.096
# 2393           Jamur Portabella Mentah             19   0.300   2.200
# 2394                       Jamur Tiram              5   0.035   0.200
#
#       Protein  Water
# 0       0.900    7.6
# 1       7.800   53.6
# 2       0.800    0.0
# 3       1.500   14.7
# ...

# %%
df_vitamin = df.loc[:,['food','Vitamin A','Vitamin B1','Vitamin B11','Vitamin B12','Vitamin B2','Vitamin B3',
                       'Vitamin B5','Vitamin B6','Vitamin C','Vitamin D','Vitamin E','Vitamin K']]
df_vitamin
# Out:
#                                   food  Vitamin A  Vitamin B1  Vitamin B11  \
# 0                            Krim Keju      0.200       0.033        0.064
# 1                      Keju Neufchatel      0.200       0.099        0.079
# 2     Requeijao Cremoso Light Catupiry      0.000       0.000        0.000
# 3                         Keju Ricotta      0.075       0.019        0.079
# 4               Krim Keju Rendah Lemak      0.016       0.080        0.062
# ...                                ...        ...         ...          ...
# 2390                    Telinga Yahudi      0.000       0.002        0.009
# 2391                       Jamur Enoki      0.000       0.000        0.087
# 2392                       Jamur Morel      0.000       0.000        0.062
# 2393           Jamur Portabella Mentah      0.000       0.064        0.075
# 2394                       Jamur Tiram      0.000       0.000        0.016
#
# ...

# %%
print(df.columns.to_list())
# Out:
# ['food', 'Caloric Value', 'Fat', 'Saturated Fats', 'Monounsaturated Fats', 'Polyunsaturated Fats', 'Carbohydrates', 'Sugars', 'Protein', 'Dietary Fiber', 'Cholesterol', 'Sodium', 'Water', 'Vitamin A', 'Vitamin B1', 'Vitamin B11', 'Vitamin B12', 'Vitamin B2', 'Vitamin B3', 'Vitamin B5', 'Vitamin B6', 'Vitamin C', 'Vitamin D', 'Vitamin E', 'Vitamin K', 'Calcium', 'Copper', 'Iron', 'Magnesium', 'Manganese', 'Phosphorus', 'Potassium', 'Selenium', 'Zinc', 'Nutrition Density']

# %%
df_mineral = df.loc[:,['food','Calcium','Zinc','Iron','Magnesium']]
df_mineral
# Out:
#                                   food  Calcium   Zinc   Iron  Magnesium
# 0                            Krim Keju    0.008  0.039  0.082      0.027
# 1                      Keju Neufchatel   99.500  0.700  0.100      8.500
# 2     Requeijao Cremoso Light Catupiry    0.000  0.000  0.000      0.000
# 3                         Keju Ricotta    0.097  0.035  0.097      0.096
# 4               Krim Keju Rendah Lemak   22.200  0.053  0.008      1.200
# ...                                ...      ...    ...    ...        ...
# 2390                    Telinga Yahudi   15.800  0.700  0.600     24.800
# 2391                       Jamur Enoki    0.000  0.096  0.099      0.034
# 2392                       Jamur Morel    0.000  0.069  0.056      1.600
# 2393           Jamur Portabella Mentah    2.600  0.500  0.300      0.000
# 2394                       Jamur Tiram    0.000  0.048  0.008      0.200
#
# [2395 rows x 5 columns]

# %%
df_main_nutrients.sort_values(by='Caloric Value',ascending=False).head(10)
# Out:
#                                                 food  Caloric Value    Fat  \
# 1437                             Daging Angsa Mentah           6077  550.7
# 1374                       Piknik Lengan Babi Mentah           5298  343.4
# 1376                      Piknik Lengan Babi Dimasak           5292  322.7
# 1430                                 Daging Duck Raw           5123  498.8
# 1372                                      Bakat Babi           3683  402.3
# 1339  Daging Babi Daging Babi Panggang Mentah Mentah           3644  182.8
# 1403                           Babi Spareribs Mentah           3593  303.5
# 1406                              Dada Kalkun Mentah           3554  158.9
# 999                             Kelapa Kelapa Kelapa           3336   71.5
# 1438                       Payudara Turki Dipanggang           3266  128.0
#
#       Sugars  Protein   Water
# 1437     0.0    259.8   813.4
# 1374     0.0    513.6  1875.9
# 1376     0.0    560.3  1351.9
# ...
